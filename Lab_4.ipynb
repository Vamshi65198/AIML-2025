# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamshi65198/AIML-2025/blob/main/Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 10%    -122.300000    33.65000           13.000000    907.900000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# 90%    -117.269000    38.48000           46.000000   4535.300000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df['median_house_value'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['median_house_value'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# population           0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070869    0.111572    0.051062      -0.018701
# latitude                 -0.068245   -0.117318   -0.068296      -0.072363
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True,linewidths=8)
# Out:
# <Axes: >

# %%
l_column=list(df.columns)
len_feature=len(l_column)
l_column,len_feature
# Out:
# (['longitude',
#   'latitude',
#   'housing_median_age',
#   'total_rooms',
#   'total_bedrooms',
#   'population',
#   'households',
#   'median_income',
#   'median_house_value'],
#  9)

# %%
x=df[l_column[0:len_feature-6]]
y=df[l_column[len_feature-1]]

# %%
print("Feature set size",x.shape)
print("Feature set size",y.shape)
# Out:
# Feature set size (3000, 3)
# Feature set size (3000,)

# %%
x.head()
# Out:
#    longitude  latitude  housing_median_age
# 0    -122.05     37.37                27.0
# 1    -118.30     34.26                43.0
# 2    -117.81     33.78                27.0
# 3    -118.36     33.82                28.0
# 4    -119.67     36.33                19.0

# %%
y.head()
# Out:
# 0    344700.0
# 1    176500.0
# 2    270500.0
# 3    330000.0
# 4     81700.0
# Name: median_house_value, dtype: float64

# %% [markdown]
# part-2

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=123)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-197d97b3adca> in <cell line: 1>()
# ----> 1 X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=123)
#
# NameError: name 'X' is not defined

# %%
print("Training feature set size:",X_train.shape)
print("Test feature set size",X_test.shape)
print("Training variable set size:",Y_train.shape)
print("Test variable set size:",Y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0bd8b13da7c5> in <cell line: 1>()
# ----> 1 print("Training feature set size:",X_train.shape)
#       2 print("Test feature set size",X_test.shape)
#       3 print("Training variable set size:",Y_train.shape)
#       4 print("Test variable set size:",Y_test.shape)
#
# NameError: name 'X_train' is not defined

# %%
d=train.describe(percentiles=[])
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a1951fe395ff> in <cell line: 1>()
# ----> 1 d=train.describe(percentiles=[])
#       2 d
#
# NameError: name 'train' is not defined

# %%
dT=d.T
dT.plot.bar(y='count')
plt.title("Bar plot the count of numericfeature",fontsize=17)
plt.xlabel("Numeric features",fontsize=17)
plt.ylabel("count",fontsize=17)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='pclass',data=train,palette='rainbow')
#sns.pairplot(train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-03cb8caa30b6> in <cell line: 1>()
# ----> 1 sns.set_style('whitegrid')
#       2 sns.countplot(x='Survived',hue='pclass',data=train,palette='rainbow')
#       3 #sns.pairplot(train)
#
# NameError: name 'sns' is not defined

# %%
sns.set_style('whitegrid')
sns.countplot(x='survived',hue='Age',data=train,palette='rainbow')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b7da358713d3> in <cell line: 2>()
#       1 sns.set_style('whitegrid')
# ----> 2 sns.countplot(x='survived',hue='Age',data=train,palette='rainbow')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2629
# -> 2630     p = _CategoricalAggPlotter(
#    2631         data=data,
#    2632         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ...

# %%
f_class_Survived=train.grouphy('Pclass')['Survived'].mean()
f_class_Survived=pd.DataFrame(f_class_Survived)
f_class_Survived
f_class_Survived.plot.bar(y='Survived')
sns.countplace(x='Survived',hue='Pclass',data=f_class_Survived,palette='rainbow')
plt.title("Fraction of passengers Survived by class",fontsize=17)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b4e20462588a> in <cell line: 1>()
# ----> 1 f_class_Survived=train.grouphy('Pclass')['Survived'].mean()
#       2 f_class_Survived=pd.DataFrame(f_class_Survived)
#       3 f_class_Survived
#       4 f_class_Survived.plot.bar(y='Survived')
#       5 sns.countplace(x='Survived',hue='Pclass',data=f_class_Survived,palette='rainbow')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'grouphy'

# %% [markdown]
# part-2

# %%
a=list(f_class_Age['Age'])
def impute_age(cols):
  Age = cols[0]
  Pclass = cols[1]
  if pd.isnull(Age):
    if Pclass == 1:
      return a[0]
    elif Pclass == 2:
      return a[1]
    else:
      return a[2]
  else:train['Age']=train[[]]
    return Age

# %%
from skeleton.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(
    train.drop('survived',axis=1),train['survived'],
    test_size=0.20,random_state=111)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
nsimu=201
penalty=[0]*nsimu
logmodel=[0]*nsimu
predictions = [0]*nsimu

class_report = [0]*nsimu

f1=[0]*nsimu

for i in range(1,nsimu):
  logmodel[i] = (LogisticRegression(C=1/1000,tol=le-4,max_iter=int(le6),n_jobs=4))
  logmodel[i].fit(X_train,Y_train)

logmodel[i].fit(X_train,y_train)

predictions [i] = logmodel[i].predict(X_test)

class_report[i] = classification_report(y_test,

predictions

l=class_report[i].split() f1[i] = l[len(1)-2]

penalty[i]=1000/i

plt.scatter(penalty [1:len (penalty)-2], 11 [1:len(f1)-2])

plt.title("F1-score vs. regularization parameter", fontsize

plt.xlabel("Penalty parameter", fontsize=17)

plt.ylabel("F1-score on test data", fontsize=17)

plt.show()
